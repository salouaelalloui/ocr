# %%
# import pytesseract
# import cv2
# from PIL import Image
# pytesseract.pytesseract.tesseract_cmd="C:\\Program Files\\Tesseract-OCR\\tesseract.exe"

# # Chargement de l'image
# image = Image.open('D:/y.jpeg')

# # Application de l'OCR
# text = pytesseract.image_to_string(image, lang='fra')

# # Affichage du texte extrait
# print(text)

# %%
import cv2
import pytesseract

# Chemin vers l'exécutable Tesseract (à adapter selon votre installation)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Chargement de l'image
image_path = r'D:\re.jpeg'
img = cv2.imread(image_path)
if img is not None:
    # Your image processing code here
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
else:
    print("Error: The input image is empty.")

# Conversion de l'image en niveaux de gris
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Binarisation de l'image
# 150 est la valeur de seuil. Tous les pixels ayant une valeur inférieure à 150 deviendront noirs.
# cv2.THRESH_BINARY est le type de seuillage appliqué ici. Dans ce cas, si la valeur du pixel est inférieure à 150, le pixel devient noir (0), sinon il devient blanc (255).
_, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)

output_path = 'thresh_output.jpg'  # Chemin de sortie pour l'image seuillée

cv2.imwrite(output_path, thresh)

# Détection des contours dans l'image seuillée / RETR_EXTERNAL pour détecter les contours extérieurs
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Dessiner les contours sur l'image originale (pour visualisation)
cv2.drawContours(img, contours, -1, (0, 255, 0), 2)  # Dessine tous les contours trouvés en vert

# Enregistrement de l'image avec les contours dessinés
output_path_with_contours = 'image_with_contours.jpg'
cv2.imwrite(output_path_with_contours, img)

# Extraction du texte en parcourant les contours détectés
extracted_text = ''
for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    
    # Récupération de la région d'intérêt (ROI) pour l'extraction de texte
    roi = img[y:y+h, x:x+w]
    # Extraction de texte à partir de la ROI avec Tesseract OCR
    text = pytesseract.image_to_string(roi, lang='eng')  # Choisir la langue appropriée
    extracted_text += text + '\n'

# Affichage du texte extrait
print(extracted_text)
# Out:
# py
#
# ie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ———
#
# 203014
# ALSA TANGER S.- A.
# www.alsa ma/tanger
# Ligne; 049002 12 GARE TRAIN - IBERIA - BOU
# Arrét: 770296 TRIAL ATLAS
# Etudiant FAC
# Num ; 4227-02030) 4-090584-0664082 1
# Date: 70/11/2023 Heure: 09:47
# Carte: B06DF/923A8N04
# 69971

# %%
# app.py

from flask import Flask, request, jsonify
import cv2
import numpy as np
import pytesseract
from flask_cors import CORS
app = Flask(__name__)
CORS(app)
# Chemin vers l'exécutable Tesseract (à adapter selon votre installation)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

@app.route('/process_image', methods=['POST'])
def process_image():
    try:
        image_file = request.files['image']
        image = cv2.imdecode(np.frombuffer(image_file.read(), np.uint8), cv2.IMREAD_COLOR)

        if image is not None:
            # Your image processing code here
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

            # Binarisation de l'image
            _, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)

            # Détection des contours dans l'image seuillée / RETR_EXTERNAL pour détecter les contours extérieurs
            contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

            # Dessiner les contours sur l'image originale
            cv2.drawContours(image, contours, -1, (0, 255, 0), 2)

            # Convert the thresholded image with contours to string using OCR
            text = pytesseract.image_to_string(thresh)

            return jsonify({'text': text})
        else:
            return jsonify({'error': 'Error: The input image is empty.'})
    except Exception as e:
        return jsonify({'error': str(e)})

if __name__ == '__main__':
    app.run(debug=False)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Dec/2023 14:27:25] "POST //process_image HTTP/1.1" 200 -

# %%
# app.py

from flask import Flask, request, jsonify
import cv2
import numpy as np
import pytesseract

app = Flask(__name__)

# Chemin vers l'exécutable Tesseract (à adapter selon votre installation)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

@app.route('/process_image', methods=['POST'])
def process_image():
    try:
        image_file = request.files['image']
        image = cv2.imdecode(np.frombuffer(image_file.read(), np.uint8), cv2.IMREAD_COLOR)

        if image is not None:
            # Your image processing code here
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

            # Binarisation de l'image
            _, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)

            # Détection des contours dans l'image seuillée / RETR_EXTERNAL pour détecter les contours extérieurs
            contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

            # Dessiner les contours sur l'image originale
            cv2.drawContours(image, contours, -1, (0, 255, 0), 2)

            # Convert the thresholded image with contours to string using OCR
            text = pytesseract.image_to_string(thresh)

            return jsonify({'text': text})
        else:
            return jsonify({'error': 'Error: The input image is empty.'})
    except Exception as e:
        # Print the exception traceback
        import traceback
        traceback.print_exc()
        return jsonify({'error': str(e)})

if __name__ == '__main__':
    app.run(debug=True)
